# %% [markdown]
# ## Load/import packages

# %%
import json
import cv2
import numpy as np
import matplotlib.pyplot as plt

from os import listdir, mkdir
from os.path import splitext
from os.path import join

# %matplotlib inline

# %% [markdown]
# ## Pre-processing
# 1. Apply illumination normalization (histogram equalization)
# 2. Pose normalization
# 3. Store the image in a named folder same name as video. The image should be stored under the as videoname_frameXXXX ✔
# 4. Data augmentation to upsample some classes

# %% [markdown]
# ## Directories
# ### Aff-Wild2

# %%
from load_filenames import (AW2_cropped_aligned_dir, 
                            AW2_cropped_aligned_folders, 
                            AW2_train_FN_split,
                            AW2_val_FN_split)

# %%
AW2_cropped_aligned_dir
# Out:
# 'D:\\Aff-Wild2 Dataset\\Aff-wild2\\Images\\cropped_aligned'

# %%
AW2_cropped_aligned_folders
# Out:
# ['1-30-1280x720',
#  '10-60-1280x720',
#  '10-60-1280x720_right',
#  '100-29-1080x1920',
#  '101-30-1080x1920',
#  '102',
#  '102-30-640x360',
#  '103',
#  '103-30-384x480',
#  '104-17-720x480',
#  '105',
#  '105-30-1280x720',
#  '106',
#  '106-30-720x1280',
#  '107',
#  '107-30-640x480',
#  '108',
#  '108-15-640x480',
#  '109-30-1280x720',
#  '11-24-1920x1080',
#  '110',
#  '110-30-270x480',
#  '111',
#  '111-25-1920x1080',
#  '112',
#  '112-30-640x360',
#  '113',
#  '113-60-1280x720',
#  '114',
#  '114-30-1280x720',
#  '115-30-1280x720',
#  '116',
#  '116-30-1280x720',
#  '117',
#  '117-25-1920x1080',
#  '118',
#  '118-30-640x480',
#  '119',
#  '119-30-848x480',
#  '12-24-1920x1080',
#  '120',
#  '120-30-1280x720',
#  '121',
#  '121-24-1920x1080',
#  '122',
#  '122-60-1920x1080-1',
#  '122-60-1920x1080-2',
#  '122-60-1920x1080-3',
#  '122-60-1920x1080-4',
#  '122-60-1920x1080-5',
#  '123',
#  '123-25-1920x1080',
#  '124-30-720x1280',
#  '125',
#  '125-25-1280x720',
#  '126',
#  '126-30-1080x1920',
#  '127',
#  '127-30-1280x720',
#  '128',
#  '128-24-1920x1080',
#  '129',
#  '129-24-1280x720',
#  '13-30-1920x1080',
#  '130',
#  '130-25-1280x720_left',
#  '130-25-1280x720_right',
#  '131',
#  '131-30-1920x1080',
#  '132',
#  '132-30-426x240',
#  '133',
#  '133-30-1280x720',
#  '134',
#  '134-30-1280x720',
#  '135',
#  '135-24-1920x1080_left',
#  '135-24-1920x1080_right',
#  '136',
#  '136-30-1920x1080',
#  '137',
#  '137-30-1920x1080',
#  '138',
#  '138-30-1280x720',
#  '139',
#  '139-14-720x480',
#  '14-30-1920x1080',
#  '140',
#  '140-30-632x360',
#  '141',
#  '143',
#  '144',
#  '146',
#  '147',
#  '148',
#  '149',
#  '15-24-1920x1080',
#  '150',
#  '151',
#  '153',
#  '154',
#  '155',
#  '156',
#  '157',
#  '158',
#  '159',
#  '16-30-1920x1080',
#  '160',
#  '161',
#  '162',
#  '163',
#  '164',
#  '165',
#  '166',
#  '167',
#  '168',
#  '169',
#  '17-24-1920x1080',
#  '171',
#  '172',
#  '175',
#  '176',
#  '177',
#  '178',
#  '179',
#  '18-24-1920x1080',
#  '181',
#  '182',
#  '183',
#  '184',
#  '185',
#  '186',
#  '187',
#  '188',
#  '189',
#  '19-24-1920x1080',
#  '190',
#  '191',
#  '192',
#  '193',
#  '194',
#  '195',
#  '196',
#  '197',
#  '198',
#  '199',
#  '2-30-640x360',
#  '20-24-1920x1080',
#  '200',
#  '201',
#  '202',
#  '203',
#  '204',
#  '206',
#  '207',
#  '208',
#  '209',
#  '21-24-1920x1080',
#  '210',
#  '211',
#  '212',
#  '213',
#  '214',
#  '215',
#  '216',
#  '218',
#  '219',
#  '22-30-1920x1080',
#  '220',
#  '221',
#  '223',
#  '224',
#  '225',
#  '226',
#  '227',
#  '228',
#  '229',
#  '23-24-1920x1080',
#  '230',
#  '231',
#  '232',
#  '233',
#  '234',
#  '235',
#  '236',
#  '237',
#  '238',
#  '239',
#  '24-30-1920x1080-1',
#  '24-30-1920x1080-2',
#  '240',
#  '241',
#  '242',
#  '243',
#  '244',
#  '245',
#  '246',
#  '247',
#  '248',
#  '249',
#  '25-25-600x480',
#  '250',
#  '251',
#  '252',
#  '253',
#  '254',
#  '255',
#  '256',
#  '257',
#  '258',
#  '259',
#  '26-60-1280x720',
#  '260',
#  '261',
#  '262',
#  '264',
#  '265',
#  '266',
#  '267',
#  '268',
#  '269',
#  '27-60-1280x720',
#  '270',
#  '271',
#  '272',
#  '273',
#  '274',
#  '275',
#  '276',
#  '277',
#  '278',
#  '279',
#  '28-30-1280x720-1',
#  '28-30-1280x720-2',
#  '28-30-1280x720-3',
#  '28-30-1280x720-4',
#  '280',
#  '281',
#  '282',
#  '283',
#  '284',
#  '285',
#  '286',
#  '287',
#  '288',
#  '289',
#  '29-24-1280x720',
#  '290',
#  '291',
#  '292',
#  '293',
#  '294',
#  '295',
#  '296',
#  '297',
#  '298',
#  '299',
#  '3-25-1920x1080',
#  '30-30-1920x1080_left',
#  '30-30-1920x1080_right',
#  '303',
#  '304',
#  '305',
#  '306',
#  '307',
#  '308',
#  '309',
#  '31-30-1920x1080',
#  '311',
#  '312',
#  '313',
#  '314',
#  '315',
#  '317',
#  '318',
#  '319',
#  '32-60-1920x1080',
#  '320',
#  '321',
#  '322',
#  '323',
#  '324',
#  '325',
#  '326',
#  '327',
#  '328',
#  '329',
#  '33-30-1920x1080',
#  '330',
#  '331',
#  '332',
#  '334',
#  '335',
#  '336',
#  '337',
#  '339',
#  '34-25-1920x1080',
#  '341',
#  '344',
#  '345',
#  '346',
#  '347',
#  '348',
#  '349',
#  '35-30-1920x1080',
#  '350',
#  '353',
#  '354',
#  '355',
#  '357',
#  '358',
#  '359',
#  '36-24-1280x720',
#  '360',
#  '361',
#  '362',
#  '363',
#  '364',
#  '365',
#  '367',
#  '368',
#  '369',
#  '37-30-1280x720',
#  '370',
#  '371',
#  '372',
#  '373',
#  '374',
#  '375',
#  '376',
#  '377',
#  '378',
#  '38-30-1920x1080',
#  '380',
#  '381',
#  '382',
#  '383',
#  '384',
#  '385',
#  '386',
#  '387',
#  '388',
#  '389',
#  '39-25-424x240',
#  '391',
#  '392',
#  '393',
#  '394',
#  '395',
#  '398',
#  '399',
#  '4-30-1920x1080',
#  '40-30-1280x720',
#  '400',
#  '402',
#  '403',
#  '406',
#  '407',
#  '408',
#  '409',
#  '41-24-1280x720',
#  '412',
#  '415',
#  '416',
#  '418',
#  '419',
#  '42-30-480x480',
#  '420',
#  '421',
#  '423',
#  '424',
#  '425',
#  '426',
#  '427',
#  '428',
#  '429',
#  '43-30-406x720',
#  '430',
#  '433',
#  '434',
#  '435',
#  '439',
#  '44-25-426x240',
#  '440',
#  '441',
#  '446',
#  '447',
#  '448',
#  '449',
#  '45-24-1280x720',
#  '450',
#  '46-30-484x360_left',
#  '46-30-484x360_right',
#  '47-30-654x480',
#  '48-30-720x1280',
#  '49-30-1280x720_left',
#  '49-30-1280x720_right',
#  '5-60-1920x1080-1',
#  '5-60-1920x1080-2',
#  '5-60-1920x1080-3',
#  '5-60-1920x1080-4',
#  '50-30-1920x1080',
#  '51-30-1280x720',
#  '52-30-1280x720_left',
#  '52-30-1280x720_right',
#  '53-30-360x480',
#  '54-30-1080x1920',
#  '55-25-1280x720',
#  '56-30-1080x1920',
#  '57-25-426x240',
#  '58-30-640x480',
#  '59-30-1280x720',
#  '6-30-1920x1080_left',
#  '6-30-1920x1080_right',
#  '60-30-1920x1080',
#  '61-24-1920x1080',
#  '62-30-654x480',
#  '63-30-1920x1080',
#  '64-24-640x360',
#  '65-30-400x228',
#  '66-25-1080x1920',
#  '67-24-640x360',
#  '68-24-1920x1080',
#  '69-25-854x480',
#  '7-60-1920x1080',
#  '70-30-720x1280',
#  '71-30-1920x1080',
#  '72-30-1280x720',
#  '74-25-1920x1080',
#  '75-30-960x720',
#  '76-30-640x280',
#  '77-30-1280x720',
#  '78-30-960x720',
#  '79-30-960x720',
#  '8-30-1280x720',
#  '80-30-320x240',
#  '81-30-576x360',
#  '82-25-854x480',
#  '83-24-1920x1080',
#  '84-30-1920x1080',
#  '85-24-1280x720',
#  '86-24-1920x1080',
#  '87-25-1920x1080',
#  '88-30-360x480',
#  '89-30-1080x1920',
#  '9-15-1920x1080',
#  '90-30-1080x1920',
#  '91-30-1920x1080',
#  '92-24-1920x1080',
#  '93-24-640x360',
#  '94-30-1920x1080',
#  '95-24-1920x1080',
#  '96-30-1280x720',
#  '97-29-1920x1080',
#  '98-30-360x360',
#  '99-30-720x720',
#  'video1',
#  'video10_1_left',
#  'video10_1_right',
#  'video11',
#  'video12',
#  'video13',
#  'video14',
#  'video15',
#  'video16',
#  'video17',
#  'video18',
#  'video19',
#  'video2',
#  'video20',
#  'video21',
#  'video22',
#  'video23',
#  'video24',
#  'video25',
#  'video26',
#  'video27',
#  'video28',
#  'video29_left',
#  'video29_right',
#  'video2_left',
#  'video3',
#  'video30',
#  'video32',
#  'video33',
#  'video34',
#  'video35',
#  'video36',
#  'video37',
#  'video38',
#  'video39',
#  'video4',
#  'video40',
#  'video41',
#  'video42',
#  'video44',
#  'video45_1',
#  'video45_2',
#  'video45_3',
#  'video45_4',
#  'video45_5',
#  'video45_6',
#  'video45_7',
#  'video46',
#  'video47',
#  'video48',
#  'video49_left',
#  'video49_right',
#  'video51',
#  'video52',
#  'video53',
#  'video54',
#  'video55_left',
#  'video55_right',
#  'video56',
#  'video57',
#  'video58',
#  'video59',
#  'video59_right',
#  'video5_left',
#  'video5_right',
#  'video6',
#  'video60',
#  'video61',
#  'video62',
#  'video63',
#  'video64',
#  'video65',
#  'video66',
#  'video67',
#  'video69',
#  'video7',
#  'video70',
#  'video71',
#  'video72',
#  'video73',
#  'video74_left',
#  'video74_right',
#  'video75',
#  'video76',
#  'video77',
#  'video78',
#  'video79',
#  'video8',
#  'video80',
#  'video81',
#  'video82',
#  'video83',
#  'video84',
#  'video85',
#  'video86_1',
#  'video86_2',
#  'video86_3',
#  'video87',
#  'video88',
#  'video89',
#  'video9',
#  'video90',
#  'video91',
#  'video92',
#  'video93',
#  'video94',
#  'video95',
#  'video96']

# %% [markdown]
# # Start Pre-processing

# %% [markdown]
# Each image has the shape (112, 112, 3)
#
# To illumination normalize it, the image is converted to grayscale and gets the shape (112, 112)

# %%
for folder in AW2_cropped_aligned_folders[295:]:
    print(folder)
# Out:
# 339
# 34-25-1920x1080
# 341
# 344
# 345
# 346
# 347
# 348
# 349
# 35-30-1920x1080
# 350
# 353
# 354
# 355
# 357
# 358
# 359
# 36-24-1280x720
# 360
# 361
# 362
# 363
# 364
# 365
# 367
# 368
# 369
# 37-30-1280x720
# 370
# 371
# 372
# 373
# 374
# 375
# 376
# 377
# 378
# 38-30-1920x1080
# 380
# 381
# 382
# 383
# 384
# 385
# 386
# 387
# 388
# 389
# 39-25-424x240
# 391
# 392
# 393
# 394
# 395
# 398
# 399
# 4-30-1920x1080
# 40-30-1280x720
# 400
# 402
# 403
# 406
# 407
# 408
# 409
# 41-24-1280x720
# 412
# 415
# 416
# 418
# 419
# 42-30-480x480
# 420
# 421
# 423
# 424
# 425
# 426
# 427
# 428
# 429
# 43-30-406x720
# 430
# 433
# 434
# 435
# 439
# 44-25-426x240
# 440
# 441
# 446
# 447
# 448
# 449
# 45-24-1280x720
# 450
# 46-30-484x360_left
# 46-30-484x360_right
# 47-30-654x480
# 48-30-720x1280
# 49-30-1280x720_left
# 49-30-1280x720_right
# 5-60-1920x1080-1
# 5-60-1920x1080-2
# 5-60-1920x1080-3
# 5-60-1920x1080-4
# 50-30-1920x1080
# 51-30-1280x720
# 52-30-1280x720_left
# 52-30-1280x720_right
# 53-30-360x480
# 54-30-1080x1920
# 55-25-1280x720
# 56-30-1080x1920
# 57-25-426x240
# 58-30-640x480
# 59-30-1280x720
# 6-30-1920x1080_left
# 6-30-1920x1080_right
# 60-30-1920x1080
# 61-24-1920x1080
# 62-30-654x480
# 63-30-1920x1080
# 64-24-640x360
# 65-30-400x228
# 66-25-1080x1920
# 67-24-640x360
# 68-24-1920x1080
# 69-25-854x480
# 7-60-1920x1080
# 70-30-720x1280
# 71-30-1920x1080
# 72-30-1280x720
# 74-25-1920x1080
# 75-30-960x720
# 76-30-640x280
# 77-30-1280x720
# 78-30-960x720
# 79-30-960x720
# 8-30-1280x720
# 80-30-320x240
# 81-30-576x360
# 82-25-854x480
# 83-24-1920x1080
# 84-30-1920x1080
# 85-24-1280x720
# 86-24-1920x1080
# 87-25-1920x1080
# 88-30-360x480
# 89-30-1080x1920
# 9-15-1920x1080
# 90-30-1080x1920
# 91-30-1920x1080
# 92-24-1920x1080
# 93-24-640x360
# 94-30-1920x1080
# 95-24-1920x1080
# 96-30-1280x720
# 97-29-1920x1080
# 98-30-360x360
# 99-30-720x720
# video1
# video10_1_left
# video10_1_right
# video11
# video12
# video13
# video14
# video15
# video16
# video17
# video18
# video19
# video2
# video20
# video21
# video22
# video23
# video24
# video25
# video26
# video27
# video28
# video29_left
# video29_right
# video2_left
# video3
# video30
# video32
# video33
# video34
# video35
# video36
# video37
# video38
# video39
# video4
# video40
# video41
# video42
# video44
# video45_1
# video45_2
# video45_3
# video45_4
# video45_5
# video45_6
# video45_7
# video46
# video47
# video48
# video49_left
# video49_right
# video51
# video52
# video53
# video54
# video55_left
# video55_right
# video56
# video57
# video58
# video59
# video59_right
# video5_left
# video5_right
# video6
# video60
# video61
# video62
# video63
# video64
# video65
# video66
# video67
# video69
# video7
# video70
# video71
# video72
# video73
# video74_left
# video74_right
# video75
# video76
# video77
# video78
# video79
# video8
# video80
# video81
# video82
# video83
# video84
# video85
# video86_1
# video86_2
# video86_3
# video87
# video88
# video89
# video9
# video90
# video91
# video92
# video93
# video94
# video95
# video96

# %%
from skimage import io, color, exposure
import time

# %%
AW2_normalized_dir = r"D:\Aff-Wild2 Dataset\Aff-wild2\Images\cropped_aligned_normalized"

def pre_processing():
    start = time.time()
    for folder in AW2_cropped_aligned_folders[295:]:
        folder_dir = join(AW2_cropped_aligned_dir,folder)
        frames_FN = listdir(folder_dir)
        print(f"Done! Time ran since start: {round(time.time()-start)//60 }:{round(time.time()-start)%60}")
        print(folder)
        # Create a directory with the name of the video to save all the normalized frames
        try:
            mkdir(join(AW2_normalized_dir, folder))
        except FileExistsError:
            print("Directory already exists!")

        for frame_name in frames_FN:
            if frame_name == ".DS_Store":
                continue
            frame = io.imread(join(folder_dir, frame_name))
            frame_g = color.rgb2gray(frame)
            frame_g_hist = exposure.equalize_adapthist(frame_g)
            frame_rgb_hist = color.gray2rgb(frame_g_hist)
            
            file = join(join(AW2_normalized_dir, folder), frame_name)
            io.imsave(file, (frame_rgb_hist*255).astype(np.uint8))

# %%
pre_processing()
# Out:
# Done! Time ran since start: 0:0
# 339
# Directory already exists!
# Done! Time ran since start: 0:30
# 34-25-1920x1080
# Done! Time ran since start: 1:28
# 341
# Done! Time ran since start: 2:0
# 344
# Done! Time ran since start: 2:37
# 345
# Done! Time ran since start: 3:0
# 346
# Done! Time ran since start: 3:58
# 347
# Done! Time ran since start: 4:27
# 348
# Done! Time ran since start: 5:13
# 349
# Done! Time ran since start: 5:52
# 35-30-1920x1080
# Done! Time ran since start: 9:29
# 350
# Done! Time ran since start: 9:51
# 353
# Done! Time ran since start: 10:17
# 354
# Done! Time ran since start: 11:12
# 355
# Done! Time ran since start: 11:28
# 357
# Done! Time ran since start: 11:41
# 358
# Done! Time ran since start: 11:44
# 359
# Done! Time ran since start: 12:21
# 36-24-1280x720
# Done! Time ran since start: 13:12
# 360
# Done! Time ran since start: 13:22
# 361
# Done! Time ran since start: 14:7
# 362
# Done! Time ran since start: 14:58
# 363
# Done! Time ran since start: 15:30
# 364
# Done! Time ran since start: 15:58
# 365
# Done! Time ran since start: 16:8
# 367
# Done! Time ran since start: 16:50
# 368
# Done! Time ran since start: 17:18
# 369
# Done! Time ran since start: 18:2
# 37-30-1280x720
# Done! Time ran since start: 18:29
# 370
# Done! Time ran since start: 18:49
# 371
# Done! Time ran since start: 18:55
# 372
# Done! Time ran since start: 19:15
# 373
# Done! Time ran since start: 19:41
# 374
# Done! Time ran since start: 19:52
# 375
# Done! Time ran since start: 20:20
# 376
# Done! Time ran since start: 20:55
# 377
# Done! Time ran since start: 21:31
# 378
# Done! Time ran since start: 22:6
# 38-30-1920x1080
# Done! Time ran since start: 22:32
# 380
# Done! Time ran since start: 22:53
# 381
# Done! Time ran since start: 23:6
# 382
# Done! Time ran since start: 23:32
# 383
# Done! Time ran since start: 23:56
# 384
# Done! Time ran since start: 24:28
# 385
# Done! Time ran since start: 24:57
# 386
# Done! Time ran since start: 25:16
# 387
# Done! Time ran since start: 25:43
# 388
# Done! Time ran since start: 26:25
# 389
# Done! Time ran since start: 27:10
# 39-25-424x240
# Done! Time ran since start: 27:56
# 391
# Done! Time ran since start: 28:30
# 392
# Done! Time ran since start: 29:5
# 393
# Done! Time ran since start: 29:56
# 394
# Done! Time ran since start: 30:21
# 395
# Done! Time ran since start: 31:16
# 398
# Done! Time ran since start: 31:50
# 399
# Done! Time ran since start: 32:46
# 4-30-1920x1080
# Done! Time ran since start: 34:13
# 40-30-1280x720
# Done! Time ran since start: 35:46
# 400
# Done! Time ran since start: 36:13
# 402
# Done! Time ran since start: 37:0
# 403
# Done! Time ran since start: 37:22
# 406
# Done! Time ran since start: 37:56
# 407
# Done! Time ran since start: 38:36
# 408
# Done! Time ran since start: 39:7
# 409
# Done! Time ran since start: 39:42
# 41-24-1280x720
# Done! Time ran since start: 40:47
# 412
# Done! Time ran since start: 41:4
# 415
# Done! Time ran since start: 41:33
# 416
# Done! Time ran since start: 42:41
# 418
# Done! Time ran since start: 43:12
# 419
# Done! Time ran since start: 44:22
# 42-30-480x480
# Done! Time ran since start: 44:36
# 420
# Done! Time ran since start: 45:6
# 421
# Done! Time ran since start: 45:43
# 423
# Done! Time ran since start: 46:39
# 424
# Done! Time ran since start: 47:27
# 425
# Done! Time ran since start: 48:16
# 426
# Done! Time ran since start: 48:44
# 427
# Done! Time ran since start: 48:56
# 428
# Done! Time ran since start: 49:29
# 429
# Done! Time ran since start: 49:45
# 43-30-406x720
# Done! Time ran since start: 50:7
# 430
# Done! Time ran since start: 50:26
# 433
# Done! Time ran since start: 51:10
# 434
# Done! Time ran since start: 52:4
# 435
# Done! Time ran since start: 52:23
# 439
# Done! Time ran since start: 52:48
# 44-25-426x240
# Done! Time ran since start: 52:52
# 440
# Done! Time ran since start: 53:18
# 441
# Done! Time ran since start: 53:44
# 446
# Done! Time ran since start: 54:8
# 447
# Done! Time ran since start: 54:49
# 448
# Done! Time ran since start: 55:29
# 449
# Done! Time ran since start: 56:4
# 45-24-1280x720
# Done! Time ran since start: 57:6
# 450
# Done! Time ran since start: 58:47
# 46-30-484x360_left
# Done! Time ran since start: 59:12
# 46-30-484x360_right
# Done! Time ran since start: 59:36
# 47-30-654x480
# Done! Time ran since start: 60:14
# 48-30-720x1280
# Done! Time ran since start: 60:30
# 49-30-1280x720_left
# Done! Time ran since start: 60:37
# 49-30-1280x720_right
# Done! Time ran since start: 60:44
# 5-60-1920x1080-1
# Done! Time ran since start: 61:44
# 5-60-1920x1080-2
# Done! Time ran since start: 62:46
# 5-60-1920x1080-3
# Done! Time ran since start: 63:50
# 5-60-1920x1080-4
# Done! Time ran since start: 64:39
# 50-30-1920x1080
# Done! Time ran since start: 65:6
# 51-30-1280x720
# Done! Time ran since start: 65:31
# 52-30-1280x720_left
# Done! Time ran since start: 65:49
# 52-30-1280x720_right
# Done! Time ran since start: 66:7
# 53-30-360x480
# Done! Time ran since start: 66:17
# 54-30-1080x1920
# Done! Time ran since start: 67:15
# 55-25-1280x720
# Done! Time ran since start: 67:30
# 56-30-1080x1920
# Done! Time ran since start: 68:12
# 57-25-426x240
# Done! Time ran since start: 68:15
# 58-30-640x480
# Done! Time ran since start: 68:43
# 59-30-1280x720
# Done! Time ran since start: 69:59
# 6-30-1920x1080_left
# Done! Time ran since start: 71:16
# 6-30-1920x1080_right
# Done! Time ran since start: 72:29
# 60-30-1920x1080
# Done! Time ran since start: 73:14
# 61-24-1920x1080
# Done! Time ran since start: 74:44
# 62-30-654x480
# Done! Time ran since start: 76:44
# 63-30-1920x1080
# Done! Time ran since start: 77:9
# 64-24-640x360
# Done! Time ran since start: 77:57
# 65-30-400x228
# Done! Time ran since start: 79:4
# 66-25-1080x1920
# Done! Time ran since start: 79:33
# 67-24-640x360
# Done! Time ran since start: 80:7
# 68-24-1920x1080
# Done! Time ran since start: 81:17
# 69-25-854x480
# Done! Time ran since start: 84:22
# 7-60-1920x1080
# Done! Time ran since start: 88:11
# 70-30-720x1280
# Done! Time ran since start: 88:39
# 71-30-1920x1080
# Done! Time ran since start: 89:53
# 72-30-1280x720
# Done! Time ran since start: 91:12
# 74-25-1920x1080
# Done! Time ran since start: 92:6
# 75-30-960x720
# Done! Time ran since start: 92:26
# 76-30-640x280
# Done! Time ran since start: 92:44
# 77-30-1280x720
# Done! Time ran since start: 93:42
# 78-30-960x720
# Done! Time ran since start: 94:27
# 79-30-960x720
# Done! Time ran since start: 94:52
# 8-30-1280x720
# Done! Time ran since start: 96:29
# 80-30-320x240
# Done! Time ran since start: 97:25
# 81-30-576x360
# Done! Time ran since start: 98:1
# 82-25-854x480
# Done! Time ran since start: 98:56
# 83-24-1920x1080
# Done! Time ran since start: 99:51
# 84-30-1920x1080
# Done! Time ran since start: 100:15
# 85-24-1280x720
# Done! Time ran since start: 100:42
# 86-24-1920x1080
# Done! Time ran since start: 101:32
# 87-25-1920x1080
# Done! Time ran since start: 101:50
# 88-30-360x480
# Done! Time ran since start: 102:29
# 89-30-1080x1920
# Done! Time ran since start: 102:35
# 9-15-1920x1080
# Done! Time ran since start: 110:42
# 90-30-1080x1920
# Done! Time ran since start: 111:58
# 91-30-1920x1080
# Done! Time ran since start: 113:50
# 92-24-1920x1080
# Done! Time ran since start: 115:16
# 93-24-640x360
# Done! Time ran since start: 115:36
# 94-30-1920x1080
# Done! Time ran since start: 115:57
# 95-24-1920x1080
# Done! Time ran since start: 116:25
# 96-30-1280x720
# Done! Time ran since start: 117:24
# 97-29-1920x1080
# Done! Time ran since start: 117:59
# 98-30-360x360
# Done! Time ran since start: 119:9
# 99-30-720x720
# Done! Time ran since start: 119:27
# video1
# Done! Time ran since start: 122:1
# video10_1_left
# Done! Time ran since start: 122:44
# video10_1_right
# Done! Time ran since start: 123:24
# video11
# Done! Time ran since start: 124:7
# video12
# Done! Time ran since start: 125:5
# video13
# Done! Time ran since start: 126:52
# video14
# Done! Time ran since start: 128:8
# video15
# Done! Time ran since start: 128:53
# video16
# Done! Time ran since start: 131:1
# video17
# Done! Time ran since start: 134:45
# video18
# Done! Time ran since start: 135:22
# video19
# Done! Time ran since start: 135:29
# video2
# Done! Time ran since start: 135:48
# video20
# Done! Time ran since start: 137:39
# video21
# Done! Time ran since start: 138:47
# video22
# Done! Time ran since start: 140:29
# video23
# Done! Time ran since start: 141:56
# video24
# Done! Time ran since start: 142:47
# video25
# Done! Time ran since start: 143:24
# video26
# Done! Time ran since start: 145:12
# video27
# Done! Time ran since start: 147:54
# video28
# Done! Time ran since start: 149:20
# video29_left
# Done! Time ran since start: 151:6
# video29_right
# Done! Time ran since start: 152:53
# video2_left
# Done! Time ran since start: 152:55
# video3
# Done! Time ran since start: 154:11
# video30
# Done! Time ran since start: 155:32
# video32
# Done! Time ran since start: 155:59
# video33
# Done! Time ran since start: 157:14
# video34
# Done! Time ran since start: 158:56
# video35
# Done! Time ran since start: 159:31
# video36
# Done! Time ran since start: 159:55
# video37
# Done! Time ran since start: 161:21
# video38
# Done! Time ran since start: 161:50
# video39
# Done! Time ran since start: 163:35
# video4
# Done! Time ran since start: 163:45
# video40
# Done! Time ran since start: 164:43
# video41
# Done! Time ran since start: 165:17
# video42
# Done! Time ran since start: 166:48
# video44
# Done! Time ran since start: 168:5
# video45_1
# Done! Time ran since start: 168:13
# video45_2
# Done! Time ran since start: 168:24
# video45_3
# Done! Time ran since start: 168:27
# video45_4
# Done! Time ran since start: 168:37
# video45_5
# Done! Time ran since start: 168:41
# video45_6
# Done! Time ran since start: 168:44
# video45_7
# Done! Time ran since start: 168:46
# video46
# Done! Time ran since start: 169:17
# video47
# Done! Time ran since start: 169:25
# video48
# Done! Time ran since start: 169:50
# video49_left
# Done! Time ran since start: 170:50
# video49_right
# Done! Time ran since start: 171:49
# video51
# Done! Time ran since start: 172:32
# video52
# Done! Time ran since start: 174:17
# video53
# Done! Time ran since start: 175:36
# video54
# Done! Time ran since start: 176:12
# video55_left
# Done! Time ran since start: 177:35
# video55_right
# Done! Time ran since start: 178:57
# video56
# Done! Time ran since start: 180:43
# video57
# Done! Time ran since start: 182:4
# video58
# Done! Time ran since start: 182:7
# video59
# Done! Time ran since start: 183:13
# video59_right
# Done! Time ran since start: 184:3
# video5_left
# Done! Time ran since start: 184:27
# video5_right
# Done! Time ran since start: 184:48
# video6
# Done! Time ran since start: 185:34
# video60
# Done! Time ran since start: 185:52
# video61
# Done! Time ran since start: 185:54
# video62
# Done! Time ran since start: 186:48
# video63
# Done! Time ran since start: 186:50
# video64
# Done! Time ran since start: 187:51
# video65
# C:\Users\ion\anaconda3\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:25: UserWarning: D:\Aff-Wild2 Dataset\Aff-wild2\Images\cropped_aligned_normalized\video65\01640.jpg is a low contrast image
# C:\Users\ion\anaconda3\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:25: UserWarning: D:\Aff-Wild2 Dataset\Aff-wild2\Images\cropped_aligned_normalized\video65\02498.jpg is a low contrast image
# C:\Users\ion\anaconda3\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:25: UserWarning: D:\Aff-Wild2 Dataset\Aff-wild2\Images\cropped_aligned_normalized\video65\02499.jpg is a low contrast image
# Done! Time ran since start: 188:23
# video66
# Done! Time ran since start: 188:24
# video67
# Done! Time ran since start: 188:43
# video69
# Done! Time ran since start: 190:7
# video7
# Done! Time ran since start: 190:37
# video70
# Done! Time ran since start: 192:33
# video71
# Done! Time ran since start: 194:25
# video72
# Done! Time ran since start: 194:26
# video73
# Done! Time ran since start: 195:27
# video74_left
# Done! Time ran since start: 198:45
# video74_right
# Done! Time ran since start: 202:11
# video75
# Done! Time ran since start: 202:17
# video76
# Done! Time ran since start: 203:1
# video77
# Done! Time ran since start: 203:34
# video78
# Done! Time ran since start: 203:38
# video79
# Done! Time ran since start: 204:19
# video8
# Done! Time ran since start: 205:21
# video80
# Done! Time ran since start: 205:26
# video81
# Done! Time ran since start: 206:51
# video82
# Done! Time ran since start: 208:43
# video83
# Done! Time ran since start: 209:10
# video84
# Done! Time ran since start: 209:16
# video85
# Done! Time ran since start: 210:41
# video86_1
# Done! Time ran since start: 211:0
# video86_2
# Done! Time ran since start: 211:9
# video86_3
# Done! Time ran since start: 211:13
# video87
# Done! Time ran since start: 211:32
# video88
# Done! Time ran since start: 213:6
# video89
# Done! Time ran since start: 213:29
# video9
# Done! Time ran since start: 214:8
# video90
# Done! Time ran since start: 214:44
# video91
# Done! Time ran since start: 214:51
# video92
# Done! Time ran since start: 215:18
# video93
# Done! Time ran since start: 215:22
# video94
# Done! Time ran since start: 215:29
# video95
# Done! Time ran since start: 217:4
# video96

# %% [markdown]
# ***

# %% [markdown]
# ## Move images in their correct train, val and test set directory

# %%
import shutil

# %%
# Load Aff-Wild2 AW2_train_classes.json
with open("AW2_train_classes.json", "r") as fp:
    AW2_train_classes = json.load(fp)
    
# Load Aff-Wild2 AW2_val_classes.json
with open("AW2_train_classes.json", "r") as fp:
    AW2_val_classes = json.load(fp)

# %%
train_dir = r'D:\Aff-Wild2 Dataset\Aff-wild2\Sets\train'
val_dir = r'D:\Aff-Wild2 Dataset\Aff-wild2\Sets\val'
test_dir = r'D:\Aff-Wild2 Dataset\Aff-wild2\Sets\test'

# %%
# Move training files
for folder, ext in AW2_train_FN_split:
    shutil.move(join(AW2_normalized_dir, folder), train_dir)
    
for folder, ext in AW2_val_FN_split:
    shutil.move(join(AW2_normalized_dir, folder), val_dir)

for folder in listdir(AW2_normalized_dir):
    shutil.move(join(AW2_normalized_dir, folder), test_dir)

# %%
# Exctract image from each videofolder and move it to the corresponding class folder
train_perclass_dir = r'D:\Aff-Wild2 Dataset\Aff-wild2\Sets_per_class\train'
label_folders = listdir(train_perclass_dir)

for folder in listdir(train_dir)[:2]:
    ##e.g. returns folder: 51-30-1280x720
    
    labels = AW2_train_classes.get(folder +'.txt')
    
    for file, label in zip(listdir(folder), labels)[:10]:
        if label in [0,1,2,3,4,5,6]:
            new_dir = join(train_perclass_dir, labelfolders[label])
        else:
            continue
        shutil.copy(join(folder,file), new_dir)
        os.rename(join(new_dir,file), join(new_dir, folder+file))
